# %%
import pandas as pd

columns = [
    "coreid",
    "source",
    "establishmentMeans",
    "threatStatus",
    "countryCode",
    "locality",
    "occurrenceStatus"
]

df = pd.read_csv('distribution.txt', sep='\t', names=columns )
df
# Out:
#            133722  \
# 0          157938
# 1          158019
# 2          158236
# 3          158275
# 4          162229
# ...           ...
# 150484   22719011
# 150485   22704002
# 150486  181767865
# 150487   22714282
# 150488   22706279
#
#        Thomas, P., Nguyen, T.H., Phan, K.L. & Nguyen, Q.H. 2013. Calocedrus rupestris Aver., Hiep & L.K.Phan. The IUCN Red List of Threatened Species 2013: https://doi.org/10.2305/IUCN.UK.2013-1.RLTS.T133722A512509.en  \
# 0       Lansdown, R.V. 2018. Narthecium reverchonii Če...
# 1       Beentje, H.J., Gereau, R.E., Hilton-Taylor, C....
# 2       Contu, S. & IUCN SSC East African Plants Red L...
# 3       IUCN SSC East African Plants Red List Authorit...
# 4       Mifsud, S. 2018. Ophrys melitensis (Salkowski)...
# ...                                                   ...
# 150484  BirdLife International 2021. Ploceus megarhync...
# 150485  BirdLife International 2020. Microptilotis vic...
# ...

# %%
df
# Out:
#            133722  \
# 0          157938
# 1          158019
# 2          158236
# 3          158275
# 4          162229
# ...           ...
# 150484   22719011
# 150485   22704002
# 150486  181767865
# 150487   22714282
# 150488   22706279
#
#        Thomas, P., Nguyen, T.H., Phan, K.L. & Nguyen, Q.H. 2013. Calocedrus rupestris Aver., Hiep & L.K.Phan. The IUCN Red List of Threatened Species 2013: https://doi.org/10.2305/IUCN.UK.2013-1.RLTS.T133722A512509.en  \
# 0       Lansdown, R.V. 2018. Narthecium reverchonii Če...
# 1       Beentje, H.J., Gereau, R.E., Hilton-Taylor, C....
# 2       Contu, S. & IUCN SSC East African Plants Red L...
# 3       IUCN SSC East African Plants Red List Authorit...
# 4       Mifsud, S. 2018. Ophrys melitensis (Salkowski)...
# ...                                                   ...
# 150484  BirdLife International 2021. Ploceus megarhync...
# 150485  BirdLife International 2020. Microptilotis vic...
# ...

# %%
df[df["Endangered"] == "Endangered"]
# Out:
#           133722  \
# 1         158019
# 13        164279
# 21        165452
# 23        165455
# 24        165456
# ...          ...
# 150478  22703776
# 150480  22704493
# 150482  22704441
# 150484  22719011
# 150487  22714282
#
#        Thomas, P., Nguyen, T.H., Phan, K.L. & Nguyen, Q.H. 2013. Calocedrus rupestris Aver., Hiep & L.K.Phan. The IUCN Red List of Threatened Species 2013: https://doi.org/10.2305/IUCN.UK.2013-1.RLTS.T133722A512509.en  \
# 1       Beentje, H.J., Gereau, R.E., Hilton-Taylor, C....
# 13      Rankou, H. 2018. Juncus tingitanus Maire & Wei...
# 21      Peraza Zurita, M.D. & Sapir, Y. 2017. Crypsis ...
# 23      Fragman-Sapir, O. 2017. Bellevalia warburgii F...
# 24      Fragman-Sapir, O. 2017. Ornithogalum fuscescen...
# ...                                                   ...
# 150478  BirdLife International 2022. Stipiturus mallee...
# 150480  BirdLife International 2022. Pardalotus quadra...
# 150482  BirdLife International 2022. Manorina melanoti...
# ...

# %%
df[""]
